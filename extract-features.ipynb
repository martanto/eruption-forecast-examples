# %%
import os
import pandas as pd
from tsfresh import extract_features
from tsfresh.feature_extraction.settings import ComprehensiveFCParameters

# %%
# extracted_features = r"D:\Projects\eruption-forecast-examples\output\VG.OJN.00.EHZ\features\extracted_features_2025-01-01-2025-07-17.csv"
extracted_features = r"D:\Projects\eruption-forecast-examples\output\VG.OJN.00.EHZ\features\extracted_relevant_2025-01-01-2025-07-17.csv"

# %%
features = pd.read_csv(extracted_features, index_col=0)

# %%
features.columns.to_list()
# Out:
# ['rsam_f2__quantile__q_0.1',
#  'rsam_f2__quantile__q_0.2',
#  'rsam_f2__quantile__q_0.3',
#  'rsam_f2__quantile__q_0.4',
#  'rsam_f2__variation_coefficient',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_50',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_97',
#  'rsam_f2__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'rsam_f2__lempel_ziv_complexity__bins_100',
#  'rsam_f2__median',
#  'rsam_f2__benford_correlation',
#  'rsam_f2__fft_aggregated__aggtype_"kurtosis"',
#  'rsam_f2__lempel_ziv_complexity__bins_10',
#  'rsam_f2__binned_entropy__max_bins_10',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_67',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_53',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_54',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_94',
#  'rsam_f2__fft_coefficient__attr_"real"__coeff_40',
#  'rsam_f2__fft_coefficient__attr_"abs"__coeff_46',
#  'rsam_f2__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
# ...

# %%
len(features)
# Out:
# 784
