# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime

# %%
df1 = pd.read_csv(
    r"D:\Projects\eruption-forecast\output\VG.OJN.00.EHZ\tremor\daily\2025-01-01.csv",
    index_col=0,
    parse_dates=True,
)

# %%
df2 = pd.read_csv(
    r"D:\Projects\whakaari-original\_tmp\_tmp_fl_00000.csv",
    index_col=0,
    parse_dates=True,
)

# %%
df1["rsam_f2"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
df2["rsam"].plot()

# %%
df1["dsar_f0-f1"].plot()

# %%
df2["vlar"].plot()
