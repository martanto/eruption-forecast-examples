# %%
import os
import pandas as pd

# %%
label_csv = r"D:\Projects\eruption-forecast\output\VG.OJN.00.EHZ\features\label_features_2025-01-03-2025-07-24.csv"

# %%
label_df = pd.read_csv(label_csv, index_col="id")

# %%
# Out:
# id
# 8      2025-01-03 00:00:00
# 9      2025-01-03 06:00:00
# 10     2025-01-03 12:00:00
# 11     2025-01-03 18:00:00
# 12     2025-01-04 00:00:00
#               ...
# 815    2025-07-23 18:00:00
# 816    2025-07-24 00:00:00
# 817    2025-07-24 06:00:00
# 818    2025-07-24 12:00:00
# 819    2025-07-24 18:00:00
# Name: datetime, Length: 812, dtype: str
