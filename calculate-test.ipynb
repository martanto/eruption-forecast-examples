# %%
from eruption_forecast import CalculateTremor

# %%
calculate = CalculateTremor(
    start_date="2025-01-05",
    end_date="2025-01-07",
    station="OJN",
    channel="EHZ",
    methods=["entropy"],
    remove_outlier_method="maximum",
    overwrite=True,
    plot_daily=True,
    save_plot=True,
    n_jobs=4,
    verbose=False,
    debug=False,
)

# %%
calculate.from_sds(sds_dir=r"D:\Data\OJN").run()
# Out:
# 2026-02-18 23:16:04 | INFO     | eruption_forecast.tremor.calculate_tremor:run:645 - Tremor data saved to D:\Projects\eruption-forecast-examples\output\VG.OJN.00.EHZ\tremor\tremor_VG.OJN.00.EHZ_2025-01-05-2025-03-25.csv
# CalculateTremor(start_date=2025-01-05, end_date=2025-01-07, station=OJN, network=VG, channel=EHZ, location=00, methods=['entropy'], output_dir=D:\Projects\eruption-forecast-examples\output, overwrite=True, n_jobs=4, remove_outlier_method=maximum, interpolate=False, value_multiplier=None, cleanup_daily_dir=False, plot_daily=True, save_plot=True, overwrite_plot=False, csv=D:\Projects\eruption-forecast-examples\output\VG.OJN.00.EHZ\tremor\tremor_VG.OJN.00.EHZ_2025-01-05-2025-03-25.csv, verbose=False, debug=False)

# %%
calculate.df
# Out:
#                          entropy
# datetime
# 2025-01-05 00:00:00  2622.952282
# 2025-01-05 00:10:00  3099.880618
# 2025-01-05 00:20:00  3267.008494
# 2025-01-05 00:30:00  3262.963287
# 2025-01-05 00:40:00  3415.641613
# ...                          ...
# 2025-03-25 23:10:00  3693.099046
# 2025-03-25 23:20:00  3138.460869
# 2025-03-25 23:30:00  2317.268423
# 2025-03-25 23:40:00  2134.042420
# 2025-03-25 23:50:00  2134.042420
#
# [1728 rows x 1 columns]
