# %%
from eruption_forecast import TremorData, CalculateTremor

# %%
calculate = CalculateTremor(
    start_date="2025-01-01",
    end_date="2025-01-03",
    station="OJN",
    channel="EHZ",
    remove_outlier_method="maximum",
    overwrite=False,
    plot_tmp=True,
    save_plot=True,
    verbose=False,
    debug=False,
)

# %%
calculate.from_sds(sds_dir=r"D:\Data\OJN").run()

# %%
tremor_data = TremorData(calculate.df)

# %%
tremor_data.csv
