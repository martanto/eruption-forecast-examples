# %%
from obspy import read, Stream

# %%
st = read(r"D:\Data\OJN\2025\VG\OJN\EHZ.D\VG.OJN.00.EHZ.D.2025.001")

# %%
def filter_stream(stream: Stream):
    _filter = stream.filter("bandpass", freqmin=0.1, freqmax=1)
    return _filter

# %%
filtered = filter_stream(st.copy())

# %%
st.plot()

# %%
filtered.plot()

# %%
filtered == st
# Out:
# False

# %%
integrate = st.copy().integrate()

# %%
integrate.plot()

# %%
st.plot()
