# %%
import pandas as pd
import os

# %%
features = r"D:\Projects\eruption-forecast\output\VG.OJN.00.EHZ\trainings\significant_features.csv"

# %%
df = pd.read_csv(features)

# %%
df.head(5)
# Out:
#                                          features        values
# 0                        rsam_f3__quantile__q_0.1  2.366738e-10
# 1  rsam_f2__fft_coefficient__attr_"abs"__coeff_50  2.718541e-10
# 2                        rsam_f2__quantile__q_0.2  6.787255e-10
# 3                  rsam_f2__variation_coefficient  7.757367e-10
# 4                        rsam_f2__quantile__q_0.1  1.092726e-09

# %%
df.groupby(by="features").count().sort_values(by="values", ascending=False)
# Out:
#                                                     values
# features
# rsam_f2__quantile__q_0.1                               463
# rsam_f2__quantile__q_0.2                               455
# rsam_f3__quantile__q_0.1                               455
# rsam_f3__quantile__q_0.2                               441
# rsam_f2__quantile__q_0.3                               423
# rsam_f4__benford_correlation                           417
# rsam_f4__quantile__q_0.4                               396
# rsam_f2__variation_coefficient                         371
# rsam_f3__quantile__q_0.3                               367
# rsam_f4__quantile__q_0.3                               358
# rsam_f2__fft_coefficient__attr_"abs"__coeff_50         328
# rsam_f3__quantile__q_0.4                               308
# rsam_f2__fft_coefficient__attr_"abs"__coeff_67         304
# rsam_f3__linear_trend__attr_"intercept"                284
# rsam_f3__variation_coefficient                         278
# ...
